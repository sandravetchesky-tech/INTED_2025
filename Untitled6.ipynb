# %% [markdown]
# <a href="https://colab.research.google.com/github/sandravetchesky-tech/INTED_2025/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))

if idade >= 16:
    print("Você já pode votar.")
else:
    print("Você ainda não pode votar.")
# Out:
# Digite sua idade: 16
# Você já pode votar.
